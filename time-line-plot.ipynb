# %%
# %pip install openai
# %pip install --upgrade --quiet  langchain-openai tiktoken chromadb langchain
import json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: Could not build wheels for chroma-hnswlib, which is required to install pyproject.toml-based projects

# %%
with open('C:/Users/rohit/OneDrive/Desktop/Time-Line-application/news.article.json', 'r') as file:
    data = json.load(file)
events = []
for article in data:
    title = article['title']
    if 'dateModified' in article.keys():
        date = article['dateModified']
        date = pd.to_datetime(date['$date'])
    description = article['articleBody']
    events.append({'date': date,'title':title, 'description': description})
df = pd.DataFrame(events)
df
# Out:
#   Cell In[5], line 1
#     with open('C:\Users\rohit\OneDrive\Desktop\Time-Line-application\news.article.json', 'r') as file:
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# # Classfication of articels into Israel - hamas war and not Israel Hamas war
# 1. I am using Title to infer wheather a articel is war related or not
# 2. I will be using Few - Shot learing apporach to classify

# %%
from openai import OpenAI
client = OpenAI(
    api_key='sk-proj-hyqfdYjpn1K74gHaEs1FT3BlbkFJ7jHOPnlDmzOCgrAf8mI7',
) 

prompt = """
Task: Classify whether an article is related to Israel or not. Use the following examples as a guide:

Example 1:
Article: "The Israeli government announced new settlements in the West Bank."
Classification: Israel

Example 2:
Article: "The economic summit discussed trade relations between Europe and Asia."
Classification: Not Israel

Example 3:
Article: "Recent clashes in Gaza have led to increased tensions in the region."
Classification: Israel

Example 4:
Article: "A new technology hub is being developed in Silicon Valley."
Classification: Not Israel

Article to classify: "Congress MP Shashi Tharoor commented on the Israel-Gaza conflict during a rally in Kerala."
Classification:
"""
chat_completion = client.chat.completions.create(  messages=[
        {
            "role": "user",
            "content": "Say this is a test",
        }
    ],
    model="gpt-3.5-turbo",max_tokens=10)
classification = response.choices[0].text.strip()
print(f'Classification: {classification}')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[15], line 28
#       2 client = OpenAI(
#       3     api_key='sk-proj-hyqfdYjpn1K74gHaEs1FT3BlbkFJ7jHOPnlDmzOCgrAf8mI7',
#       4 )
#       6 prompt = """
#       7 Task: Classify whether an article is related to Israel or not. Use the following examples as a guide:
#       8
#    (...)
#      26 Classification:
#      27 """
# ---> 28 chat_completion = client.chat.completions.create(  messages=[
#      29         {
#      30             "role": "user",
#      31             "content": "Say this is a test",
#      32         }
#      33     ],
#      34     model="gpt-3.5-turbo",max_tokens=10)
#      35 classification = response.choices[0].text.strip()
#      36 print(f'Classification: {classification}')
#
# ...

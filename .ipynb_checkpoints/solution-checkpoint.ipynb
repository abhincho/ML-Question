# %% [markdown]
# ### Import

# %%
import json

# %%
with open('news.article.json','r',encoding='utf-8') as file:
    data = json.load(file)
print(len)
# Out:
# <built-in function len>

# %%
print(len(data))
# Out:
# 37421

# %%
print(data[1500])
# Out:
# {'articleBody': 'The US military on Friday hit two sites linked to Iran\'s Islamic Revolutionary Guard Corps (IRGC) in Eastern Syria in response to recent attacks by Iranian proxies in the Middle East region.\n\nSince October 17, one US contractor has died and at least 21 US service personnel have sustained minor injuries in Iran-backed militias\' attacks on US troops deployed in Iraq and Syria.\n\nThe US Department of Defense (DoD) described the strikes as "self-defence" strikes against IRGC and affiliated groups are "a response to a series of ongoing and mostly unsuccessful attacks against US personnel" in the Middle East region. The DoD statement added that the US intention is not to escalate the situation but it would also not hesitate to take further actions if the attacks continue.\n\nThe IRGC is a military force parallel to the regular Iranian military but works independently of the regular military. The IRGC is directly under the Supreme Leader of Iran and acts as his sword a
# ...

# %%
data[2].keys()
# Out:
# dict_keys(['articleBody', 'dateModified', 'scrapedDate', 'source', 'title'])

# %%
data[2]['title']
# Out:
# "Uddhav buried Bal Thackeray's 'Hindutva' for power; may hug Hamas one day: Shinde"

# %%
import nltk
from nltk.corpus import wordnet

nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/sakatagintoki/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/sakatagintoki/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().lower())
    return synonyms

def filter_string(text):
    # Define the keywords
#     keywords = {"israel", "hamas", "war","killed","peace","terrorist","gaza","redcross","hezbollah","military","army","casuality","isaac", "herzog"}
    keywords = {"israel", "hamas", "war","terrorist","gaza","hezbollah","military","casuality","Netanyahu","qassam","airstrikes","retaliation"}


    # Generate synonyms for each keyword
    all_keywords = set(keywords)
    for keyword in keywords:
        all_keywords.update(get_synonyms(keyword))

    # Check if any of the keywords or their synonyms are in the text
    words = set(text.lower().split())
    
    match_count = sum(1 for word in words if word in all_keywords)
    if match_count >= 2:
        return True
    return False

filtered_texts = [text for text in data if filter_string(text['articleBody']+text['title'])]
print(filtered_texts)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
len(filtered_texts),type(filtered_texts)
# Out:
# (27383, list)

# %%
import string
def remove_newlines_and_nonprintable(s):
    # Remove specific characters like newlines
    s = s.replace('\n', '').replace('\r', '').replace("\'", "'")
    # Remove non-printable characters
    printable = set(string.printable)
    return ''.join(filter(lambda x: x in printable, s))
def remove_punctuation(input_string):
    # Create a translation table to map punctuation to None
    translator = str.maketrans('', '', string.punctuation)
    # Use translate to remove all punctuation
    cleaned_string = input_string.translate(translator)
    return cleaned_string

# %%
for i in range(len(filtered_texts)):
    filtered_texts[i]['articleBody'] = remove_punctuation(remove_newlines_and_nonprintable(filtered_texts[i]['articleBody']))
    filtered_texts[i]['title'] = remove_punctuation(remove_newlines_and_nonprintable(filtered_texts[i]['title']))

# %%
filtered_texts[20]['articleBody']
# Out:
# 'Thiruvananthapuram The BJP in Kerala on Friday criticised Congress Working Committee CWC member and Lok Sabha MP Shashi Tharoor for his participation in the Indian Union Muslim Leagues rally supporting Palestine labelling it a proHamas eventA day after tens of thousands of IUML supporters hit the streets of Kozhikode expressing solidarity with the people of warravaged Palestine BJP state president K Surendran expressed concern that the conflict was being used to fuel communal tensions in the stateThe IUML rally in Kozhikode was proHamas and antinational slogans had been raised throughout the programme he alleged in a press conference hereThe BJP leader alleged that Tharoors participation in the rally given his previous role as a UN diplomat goes against the countrys established stance on the issueSurendran claimed that Tharoors attendance at the rally was a move to garner votes from communal groups calling it an act of treason to support Hamas which according to him backs antiIndian
# ...

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/sakatagintoki/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
for i in range(len(filtered_texts)):
    text = filtered_texts[i]['articleBody']
    tokens = word_tokenize(text)
    tokens = [w.lower() for w in tokens]
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]
    filtered_texts[i]['articleBody'] = ' '.join(words)

# %%
filtered_texts[1]
# Out:
# {'articleBody': 'kozhikode kerala india october ani pointing out that the world was witnessing its worst tragedy congress mp shashi tharoor alleged that israels response to the october hamas terrorist attack was disproportionate as a greater number of palestinian people were killed in the past days compared to those who lost their lives in the region since the year an event organised to express solidarity with the palestine people by the indian united muslim league iuml in keralas kozhikode on thursday tharoor urged israel to end air strikes in gaza adding that india has always stood for peace since mahatama gandhisince days the world is seeing the worst humanrights tragedies we are seeing the worst tragedy terrorists attacked israel hamas is a terror group israel stopped providing food water and electricity to gaza we are condemning the bombing of israel tharoor said at the event held at kozhikode beachtharoor who had previoulsy served as an un diplomat said the ongoing air strikes 
# ...

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame.from_dict(filtered_texts)
df = df.dropna(subset=['dateModified'])
df=df.drop(columns=['scrapedDate'])
df.rename(columns={'dateModified': 'date'}, inplace=True)

# %%
df['date'] = df['date'].apply(lambda x: x['$date'])
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df
# Out:
#                                              articleBody        date  \
# 0      sanjay raut a member of the shiv sena ubt part...  2023-10-25
# 2      mumbai oct pti maharashtra chief minister ekna...  2023-10-25
# 3      october pm updated pm ist kozhikodepanakkad sy...  2023-10-26
# 4      october pm updated october am ist kozhikodesha...  2023-10-26
# 5      delhi recorded the worlds most toxic air on mo...  2023-10-23
# ...                                                  ...         ...
# 27377  by palestine chronicle staffamid israels genoc...  2024-03-30
# 27379  jordan says gaza famine can be tackled quickly...  2024-03-23
# 27380  amid escalating tensions and concerns over pot...  2024-03-31
# 27381  haaretzcom the online english edition of haare...  2024-03-28
# 27382  the un secretary general antnio guterres has c...  2024-03-31
#
#                                     source  \
# 0            https://www.thehansindia.com/
# 2                  https://thefederal.com/
# ...

# %%
# !pip install spacy
import spacy
from sklearn.cluster import DBSCAN
from tqdm import tqdm

# %%
nlp = spacy.load('en_core_web_lg')

sent_vecs = {}
docs=[]

for title in tqdm(df.title):
    doc=nlp(title)
    docs.append(doc)
    sent_vecs.update({title: doc.vector})
    
sentences = list(sent_vecs.keys())
vectors = list(sent_vecs.values())
# Out:
# 100%|████████████████████████████████████| 17936/17936 [01:27<00:00, 205.33it/s]

# %%
x=np.array(vectors)

# %%
n_classes={}

for i in tqdm(np.arange(0.001,1,0.002)):
    dbscan = DBSCAN(eps=i, min_samples=2,metric='cosine').fit(x)
    n_classes.update({i: len(pd.Series(dbscan.labels_).value_counts())})
# Out:
#  58%|███████████████████████▋                 | 289/500 [11:11<08:10,  2.32s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 4
#       1 n_classes={}
#       3 for i in tqdm(np.arange(0.001,1,0.002)):
# ----> 4     dbscan = DBSCAN(eps=i, min_samples=2,metric='cosine').fit(x)
#       5     n_classes.update({i: len(pd.Series(dbscan.labels_).value_counts())})
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
n_classes
# Out:
# {0.001: 60,
#  0.003: 109,
#  0.005: 159,
#  0.007: 203,
#  0.009000000000000001: 250,
#  0.011: 288,
#  0.013000000000000001: 331,
#  0.015: 362,
#  0.017: 388,
#  0.019000000000000003: 427,
#  0.021: 454,
#  0.023: 491,
#  0.025: 517,
#  0.027000000000000003: 543,
#  0.029: 568,
#  0.031: 596,
#  0.033: 619,
#  0.035: 657,
#  0.037000000000000005: 686,
#  0.039: 720,
#  0.041: 743,
#  0.043000000000000003: 774,
#  0.045: 793,
#  0.047: 828,
#  0.049: 864,
#  0.051000000000000004: 894,
#  0.053000000000000005: 910,
#  0.055: 936,
#  0.057: 953,
#  0.059000000000000004: 958,
#  0.061: 949,
#  0.063: 949,
#  0.065: 936,
#  0.067: 940,
#  0.069: 930,
#  0.07100000000000001: 933,
#  0.07300000000000001: 924,
#  0.075: 934,
#  0.077: 916,
#  0.079: 878,
#  0.081: 875,
#  0.083: 854,
#  0.085: 843,
#  0.08700000000000001: 816,
#  0.089: 780,
#  0.091: 761,
#  0.093: 730,
#  0.095: 702,
#  0.097: 686,
#  0.099: 661,
#  0.101: 635,
#  0.10300000000000001: 626,
#  0.10500000000000001: 610,
# ...

# %%
import matplotlib.pyplot as plt
x_values = list(n_classes.keys())
y_values= list(n_classes.values())
plt.plot(x_values, y_values, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Plot of X vs Y')

# Show the plot
plt.show()

# %%
dbscan = DBSCAN(eps=0.075, min_samples=2,metric='cosine').fit(x)

# %%
from collections import Counter

cluster_labels = DBSCAN(eps=0.075, min_samples=2,metric='cosine').fit_predict(x)

cluster_sizes = Counter(cluster_labels)

for cluster, size in cluster_sizes.items():
    print(f"{cluster}: {size}")
# Out:
# -1: 10846
# 0: 2
# 1: 2
# 2: 2
# 3: 3
# 4: 2
# 5: 2446
# 6: 2
# 7: 8
# 8: 2
# 9: 12
# 10: 3
# 11: 2
# 12: 2
# 13: 2
# 14: 4
# 15: 2
# 16: 3
# 17: 3
# 18: 2
# 19: 2
# 20: 2
# 21: 4
# 22: 2
# 23: 16
# 24: 26
# 25: 2
# 26: 2
# 27: 2
# 28: 7
# 29: 2
# 30: 2
# 31: 6
# 32: 2
# 33: 2
# 34: 2
# 35: 2
# 36: 2
# 37: 2
# 38: 2
# 39: 3
# 40: 3
# 41: 16
# 42: 2
# 43: 3
# 44: 2
# 45: 2
# 46: 5
# 47: 2
# 48: 5
# 49: 4
# 50: 2
# 51: 2
# 52: 2
# 53: 2
# 54: 8
# 55: 3
# 56: 2
# 57: 16
# 58: 2
# 59: 2
# 60: 4
# 61: 2
# 62: 2
# 63: 2
# 64: 2
# 65: 2
# 66: 2
# 67: 2
# 68: 3
# 69: 5
# 70: 2
# 71: 6
# 72: 2
# 73: 2
# 74: 2
# 75: 6
# 76: 2
# 77: 2
# 78: 5
# 79: 2
# 80: 3
# 81: 2
# 82: 2
# 83: 2
# 84: 10
# 85: 2
# 86: 2
# 87: 3
# 88: 2
# 89: 3
# 90: 4
# 91: 2
# 92: 2
# 93: 2
# 94: 2
# 95: 4
# 96: 2
# 97: 2
# 98: 3
# 99: 2
# 100: 2
# 101: 6
# 102: 2
# 103: 2
# 104: 4
# 105: 2
# 106: 3
# 107: 2
# 108: 2
# 109: 4
# 110: 2
# 111: 3
# 112: 3
# 113: 2
# 114: 2
# 115: 2
# 116: 2
# 117: 2
# 118: 2
# 119: 2
# 120: 3
# ...

# %%
for i in range(len(sentences)):
    if(sentences[i] ==  'Hamas spokesperson says had no intention to kill Israelis during Oct 7 infiltration cuts interview midway'):
        print(i)
        break
# Out:
# 32

# %%
results = pd.DataFrame({'label':dbscan.labels_,'sent':sentences})
res = results[results.label==24].sent.tolist()
event_df = df[df.title.isin(res)][['date','title']]
event_df['date']=pd.to_datetime(event_df.date)
event_df = event_df.sort_values(by='date').dropna()

# %%
event_df
# Out:
#             date                                              title
# 361   2023-10-25  Journalist Wael AlDahdouhs family was killed i...
# 532   2023-10-27  Al Jazeera Anchor Announces Colleagues Family ...
# 16228 2023-12-15  Israeli strike on school kills Al Jazeera came...
# 16184 2023-12-15  Al Jazeera says cameraman killed in Gaza by dr...
# 16182 2023-12-15  Israeli strike on school kills Al Jazeera came...
# 16172 2023-12-15  Israeli strike on school kills Al Jazeera came...
# 16665 2023-12-15  Al Jazeera says cameraman killed in Gaza by dr...
# 16154 2023-12-15  Israeli strike on school kills Al Jazeera came...
# 16144 2023-12-15  Israeli strike on school kills Al Jazeera came...
# 16139 2023-12-15  Al Jazeera cameraman dies after Israeli attack...
# 16137 2023-12-15  Israeli strike on school kills Al Jazeera came...
# 16135 2023-12-15  Two Al Jazeera journalists wounded in Gaza mis...
# 16117 2023-12-15  Israeli Strike Kills Al Jazeera Cameraman in Gaza
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

event_df = event_df.sort_values(by='date')

# Plotting
plt.figure(figsize=(20, 5))
plt.plot(event_df['date'], event_df.index, marker='o', linestyle='-')
plt.yticks(event_df.index, event_df['title'])
plt.xlabel('Date')
plt.ylabel('Event')
plt.title('Timeline of Events')
plt.grid(True)
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Thankyou
